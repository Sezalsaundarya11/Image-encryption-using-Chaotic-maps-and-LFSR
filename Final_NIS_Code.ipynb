# %%
00
# Out:
# Enter the path to the image file: /content/greyyyyyyyyy.jpeg
# Enter the seed value for logistic map: 0.5
# Enter the seed value for LFSR: 45
# Enter the tap value for LFSR: 89
# Enter the seed value for Henon map (x): 0.1
# Enter the seed value for Henon map (y): 0.2
# Enter the 'a' value for Henon map: 1.4
# Enter the 'b' value for Henon map: 0.3
# Image encrypted successfully!
# Image encrypted successfully!
# Do you want to decrypt the image? (yes/no): yes
# Enter the seed value for logistic map: 0.5
# Enter the seed value for LFSR: 45
# Enter the tap value for LFSR: 89
# Enter the seed value for Henon map (x): 0.1
# Enter the seed value for Henon map (y): 0.2
# Enter the 'a' value for Henon map: 1.4
# Enter the 'b' value for Henon map: 0.3
# Image decrypted successfully!
# Image decrypted successfully!
# MSE: 105.29563835072032
# Entropy (Original Image): 5.661250354830649
# Entropy (encrypted Image): 7.996638311506876
# ...

# %%
import matplotlib.pyplot as plt

# Calculate and plot histogram for the original image
original_histogram, _ = np.histogram(original_pixels.flatten(), bins=256, range=[0, 256])
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(original_histogram, color='black')
plt.title('Original Image Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')

# Calculate and plot histogram for the encrypted image
encrypted_histogram, _ = np.histogram(encrypted_pixels.flatten(), bins=256, range=[0, 256])
plt.subplot(1, 2, 2)
plt.plot(encrypted_histogram, color='black')
plt.title('Encrypted Image Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
